# %% [markdown]
# # Make some noise

# %% [markdown]
# Reachy 2 has two microphones located on each antenna and one speaker inside its torso. The audio API allows you to record and play audio files.
#
# ***Note that, for now, the audio files are located in a temporary folder on Reachy's computer and are deleted at each reboot of the robot. The file management is very basic, allowing just a list of files in a single folder.***

# %% [markdown]
# ## Manage the sound files

# %% [markdown]
# First, connect to your robot.

# %%
from reachy2_sdk import ReachySDK

reachy = ReachySDK(host='192.168.0.117')  # Replace with the actual IP
# Out:
# Local API version (1.0.21) is different from the robot's API version (1.0.19).
# Some features may not work properly.
# Please update the reachy2_core image on the robot to ensure compatibility, or downgrade your local reachy2_sdk package.
# This Reachy is in REAL mode :
# ⚠️  Be careful, you're controlling the PHYSICAL Reachy.

# %% [markdown]
# You can first check the audio files available on Reachy.

# %%
reachy.audio.get_audio_files()
# Out:
# []

# %% [markdown]
# The list may be empty if you have just started to play with Reachy. Let's add a new audio file. Reachy is able to play wav, mp3, and ogg files. Ogg files can be downloaded [here for instance](https://getsamplefiles.com/sample-audio-files/ogg).
# Make sure to change the path name in the line below. For instance */home/name/Downloads/sample-1.ogg* or *C:\Users\name\Downloads\sample-1.ogg*

# %%
reachy.audio.upload_audio_file(r'C:\Users\elima\Desktop\Tesi\AudioReachy\sample-1.ogg')
reachy.audio.upload_audio_file(r'C:\Users\elima\Desktop\Tesi\AudioReachy\sample-4.ogg')
# Out:
# True

# %% [markdown]
# Now these two files should be listed on Reachy:

# %%
reachy.audio.get_audio_files()
# Out:
# ['sample-1.ogg', 'sample-4.ogg']

# %% [markdown]
# A file can be removed if you don't want to use it. It should no longer be in the list!

# %%
reachy.audio.remove_audio_file('sample-4.ogg')
# Out:
# True

# %%
reachy.audio.get_audio_files()
# Out:
# ['sample-1.ogg']

# %% [markdown]
# ### Play a sound
#
# Once an audio file is uploaded onto Reachy, you can play it

# %%
reachy.audio.play_audio_file('sample-1.ogg')

# %% [markdown]
# Stop the playback whenever you want

# %%
reachy.audio.stop_playing()

# %% [markdown]
# ### Record a sound
#
# In a similar way, a sound can be recorded using Reachy's microphones. Only the ogg extension is allowed for now. The duration of the recording, in seconds, must be set.

# %%
reachy.audio.record_audio('tutorial.ogg', duration_secs=5)
# Out:
# True

# %% [markdown]
# The audio is recorded in the background; it may be stopped at any time.

# %%
reachy.audio.stop_recording()

# %% [markdown]
# The audio file is now on Reachy's file system, and available for listening

# %%
reachy.audio.get_audio_files()
# Out:
# ['sample-1.ogg', 'tutorial.ogg']

# %%
reachy.audio.play_audio_file('tutorial.ogg')

# %% [markdown]
# Finally, the audio file can be downloaded to your local machine.

# %%
reachy.audio.download_audio_file('tutorial.ogg', r'C:\Users\elima\Desktop\Tesi\AudioReachy')
# Out:
# True
# Exception in thread Thread-13 (_audit):
# Traceback (most recent call last):
#   File "c:\Users\elima\miniconda3\envs\reachy\lib\threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-12 (_start_sync_in_bg):
# Traceback (most recent call last):
#   File "C:\Users\elima\Desktop\Tesi\Dev\reachy2-sdk\src\reachy2_sdk\reachy_sdk.py", line 525, in _get_stream_update_loop
#     for state_update in reachy_stub.StreamReachyState(stream_req):
#   File "c:\Users\elima\miniconda3\envs\reachy\lib\site-packages\grpc\_channel.py", line 543, in __next__
#     self.run()
#   File "c:\Users\elima\miniconda3\envs\reachy\lib\threading.py", line 953, in run
#     return self._next()
#   File "c:\Users\elima\miniconda3\envs\reachy\lib\site-packages\grpc\_channel.py", line 969, in _next
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\elima\Desktop\Tesi\Dev\reachy2-sdk\src\reachy2_sdk\reachy_sdk.py", line 554, in _audit
#     raise self
# grpc._channel._MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "IOCP/Socket: Connection timed out (A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond.
#  -- 10060)"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:192.168.0.117:50051 {grpc_message:"IOCP/Socket: Connection timed out (A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond.\r\n -- 10060)", grpc_status:14}"
# >
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\elima\miniconda3\envs\reachy\lib\threading.py", line 1016, in _bootstrap_inner
#     audit_status = self._stub.Audit(self._robot.id)
#   File "c:\Users\elima\miniconda3\envs\reachy\lib\site-packages\grpc\_channel.py", line 1181, in __call__
#     self.run()
#   File "c:\Users\elima\miniconda3\envs\reachy\lib\threading.py", line 953, in run
#     return _end_unary_response_blocking(state, call, False, None)
#   File "c:\Users\elima\miniconda3\envs\reachy\lib\site-packages\grpc\_channel.py", line 1006, in _end_unary_response_blocking
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\elima\Desktop\Tesi\Dev\reachy2-sdk\src\reachy2_sdk\reachy_sdk.py", line 514, in _start_sync_in_bg
#     self._get_stream_update_loop(reachy_stub, freq=100)
#   File "C:\Users\elima\Desktop\Tesi\Dev\reachy2-sdk\src\reachy2_sdk\reachy_sdk.py", line 544, in _get_stream_update_loop
#     raise ConnectionError(f"Connection with Reachy ip:{self._host} lost, check the SDK server status.")
# ConnectionError: Connection with Reachy ip:192.168.0.117 lost, check the SDK server status.
#     raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
# grpc._channel._InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "IOCP/Socket: Connection timed out (A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond.
#  -- 10060)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"IOCP/Socket: Connection timed out (A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond.\r\n -- 10060)", grpc_status:14}"
# >
